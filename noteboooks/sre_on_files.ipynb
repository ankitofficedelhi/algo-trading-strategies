# %%
import os, pandas as pd,numpy as np
path_future = "C:\\PICKLE\\Nifty Future"
path_options = "C:\\PICKLE\\Nifty Options"
# import warnings
# warnings.filterwarnings('ignore')

# List all files in the Nifty Future folder
future_files = [os.path.join(path_future, f) for f in os.listdir(path_future) if os.path.isfile(os.path.join(path_future, f))]
future_files = [f for f in future_files if "2024" in f]
# List all files in the Nifty Options folder
option_files = [os.path.join(path_options, f) for f in os.listdir(path_options) if os.path.isfile(os.path.join(path_options, f))]
option_files = [f for f in option_files if "2024" in f]

# %%
def calculate_sl_intra(entry_time,sl,intra_sl,ce_data,pe_data):
    ce_pe_price = ce_data.loc[entry_time,'close']+pe_data.loc[entry_time,'close']

    sl_price = ce_pe_price*(1+sl/100)
    intra_sl_price = ce_pe_price*(1+intra_sl/100)
    return sl_price,ce_pe_price ,intra_sl_price

def check_sl_hit(ce_data,pe_data,sl_price,intra_sl_price):
    try:
        sl_time = ce_data[ce_data.close +  pe_data.close >= sl_price].index[0]
    except:
        sl_time = None
    try:
        intra_sl_time = ce_data[np.maximum(ce_data.high + pe_data.low, ce_data.low + pe_data.high )>= intra_sl_price].index[0]
    except:
        intra_sl_time = None

    return sl_time,intra_sl_time

def get_one_om(future_price,fpt,step):
    future_price = fpt['close'].iloc[0] if future_price is None else future_price

    return ((int(future_price/step)*step)/100)

def get_strangle_strike(start_dt, end_dt, opt: pd.DataFrame, fpt: pd.DataFrame, step: int, om=0.1, target=False, tf=1):
   
    valid_times = fpt.loc[start_dt:end_dt].index

    for current_dt in valid_times:
        future_price = fpt.loc[current_dt, 'close']
        one_om = get_one_om(future_price, fpt, step)
        target = one_om * om if not target else target
        
        # Filter options for the current time and whose closing price is >= the target
        target_od = opt[(opt.index == current_dt) & (opt['close'] >= target * tf)].sort_values(by=['close']).copy()

        # --- IMPORTANT: Handle the case where no options meet the criteria ---
        if target_od.empty:
            print(f"No options found for time {current_dt} that meet the target price criteria. Skipping.")
            continue  # Move to the next valid time

        try:
            ce_scrip = target_od.loc[target_od['scrip'].str.endswith('CE'), 'scrip'].iloc[0]
            pe_scrip = target_od.loc[target_od['scrip'].str.endswith('PE'), 'scrip'].iloc[0]
        except IndexError:
            # Handle cases where there is a CE but no PE (or vice versa)
            print(f"Could not find a matching CE/PE pair for time {current_dt}. Skipping.")
            continue

        ce_scrip_list = [ce_scrip, f"{int(ce_scrip[:-2]) - step}CE", f"{int(ce_scrip[:-2]) + step}CE"]
        pe_scrip_list = [pe_scrip, f"{int(pe_scrip[:-2]) - step}PE", f"{int(pe_scrip[:-2]) + step}PE"]

        call_list_prices, put_list_prices = [], []
        for z in range(3):
            try:
                # Get the close price for the call option
                call_list_prices.append(opt[opt['scrip'] == ce_scrip_list[z]].loc[current_dt, 'close'])
            except KeyError:
                call_list_prices.append(0)
            try:
                # Get the close price for the put option
                put_list_prices.append(opt[opt['scrip'] == pe_scrip_list[z]].loc[current_dt, 'close'])
            except KeyError:
                put_list_prices.append(0)
        
        # Initialize required_call and required_put with the first values
        required_call, required_put = call_list_prices[0], put_list_prices[0]
        min_diff = abs(required_put - required_call)
        
        target_2, target_3 = target * 2 * tf, target * 3

        # Check the initial pair
        if not ((required_put + required_call >= target_2) and (required_put + required_call <= target_3)):
            # Reset if initial pair does not meet criteria to find a better one
            required_call, required_put = None, None
            min_diff = float('inf')


        # Find the best combination of call and put from the lists
        for i in range(3):
            for j in range(3):
                current_call = call_list_prices[i]
                current_put = put_list_prices[j]
                
                # Ensure neither price is 0 (i.e., exists)
                if current_call > 0 and current_put > 0:
                    current_sum = current_call + current_put
                    current_diff = abs(current_put - current_call)
                    
                    if (current_sum >= target_2) and (current_sum <= target_3):
                        if current_diff < min_diff:
                            min_diff = current_diff
                            required_call = current_call
                            required_put = current_put
        
        # Check if a valid pair was found
        if required_call is not None and required_put is not None:
            # Get the scrip names for the found prices
            ce_scrip_final = ce_scrip_list[call_list_prices.index(required_call)]
            pe_scrip_final = pe_scrip_list[put_list_prices.index(required_put)]
            
            return ce_scrip_final, pe_scrip_final, required_call, required_put
        else:
            print(f"No suitable strangle pair found for time {current_dt} that meets the criteria. Skipping.")
            continue # Try the next current_dt
            
    # If the loop completes without finding a suitable pair, return None values
    return None, None, None, None

def backtest_strategy(opt, fut, om, entry_time, exit_time, sl, intra_sl):
    
    ce_scrip, pe_scrip, ce_price, pe_price = get_strangle_strike(entry_time, exit_time, opt, fut, 50, om=om, target=None, tf=1)
    
    opt = opt.loc[entry_time:exit_time]
    ce_data = opt[(opt['scrip'] == ce_scrip)]
    pe_data = opt[(opt['scrip'] == pe_scrip)]

    common_index = ce_data.index.intersection(pe_data.index)
    ce_data = ce_data.loc[common_index]
    pe_data = pe_data.loc[common_index]
    
    
    sl_price, ce_pe_price, intra_sl_price = calculate_sl_intra(entry_time, sl, intra_sl, ce_data, pe_data)
    print(f"sl price {sl_price} ce pe price {ce_pe_price}")
    
    total_pnl = 0
    trade_log = []
    current_entry_time = entry_time
    
    sl_time, intra_sl_time = check_sl_hit(ce_data, pe_data, sl_price, intra_sl_price)
    
    while True:
        trade_details = {
            'entry_time': current_entry_time,
            'ce_scrip': ce_scrip,
            'pe_scrip': pe_scrip,
            'entry_price': ce_pe_price
        }

        if sl_time is None and intra_sl_time is None:
            # Trade closes at the final exit time without hitting SL
            try:
                print("SL NOT HIT")
                exit_ce_pe = ce_data.loc[exit_time, 'close'] + pe_data.loc[exit_time, 'close']
                pnl = ce_pe_price - exit_ce_pe
                total_pnl += pnl
                trade_details.update({
                    'exit_time': exit_time,
                    'exit_price': exit_ce_pe,
                    'pnl': pnl,
                    'exit_reason': 'Time Exit'
                })
                trade_log.append(trade_details)
                print("total pnl ", total_pnl)
                break
            except Exception as e:
                print(e)
                print("SL NOT HIT")
                exit_ce_pe = ce_data.loc[ce_data.index[-1], 'close'] + pe_data.loc[pe_data.index[-1], 'close']
                pnl = ce_pe_price - exit_ce_pe
                total_pnl += pnl
                trade_details.update({
                    'exit_time': ce_data.index[-1],
                    'exit_price': exit_ce_pe,
                    'pnl': pnl,
                    'exit_reason': 'Time Exit (Partial Data)'
                })
                trade_log.append(trade_details)
                print("total pnl ", total_pnl)
                break

        elif sl_time is not None and intra_sl_time is not None:
            if sl_time < intra_sl_time:
                # Regular SL is hit
                print("SL HIT : ", sl_time)
                pnl = ce_pe_price - sl_price
                total_pnl += pnl
                trade_details.update({
                    'exit_time': sl_time,
                    'exit_price': sl_price,
                    'pnl': pnl,
                    'exit_reason': 'SL Hit'
                })
                trade_log.append(trade_details)
                print("pnl ", pnl)
                print('total pnl ', total_pnl)
                
                # Re-enter the next trade
                current_entry_time = sl_time
                sl_price, ce_pe_price, intra_sl_price = calculate_sl_intra(current_entry_time, sl, intra_sl, ce_data, pe_data)
                sl_time, intra_sl_time = check_sl_hit(ce_data, pe_data, sl_price, intra_sl_price)
                print("next trade hit")
            else:
                # Intra SL is hit
                print("INTRA SL HIT ", intra_sl)
                pnl = ce_pe_price - intra_sl_price
                trade_details.update({
                    'exit_time': intra_sl_time,
                    'exit_price': intra_sl_price,
                    'pnl': pnl,
                    'exit_reason': 'Intra SL Hit'
                })
                trade_log.append(trade_details)
                print("pnl ", pnl)
                break

        elif sl_time is not None and intra_sl_time is None:
            # Only regular SL is hit
            print("SL HIT : ", sl_time)
            pnl = ce_pe_price - sl_price
            total_pnl += pnl
            trade_details.update({
                'exit_time': sl_time,
                'exit_price': sl_price,
                'pnl': pnl,
                'exit_reason': 'SL Hit'
            })
            trade_log.append(trade_details)
            print("pnl ", pnl)
            print('total pnl ', total_pnl)
            
            # Re-enter the next trade
            current_entry_time = sl_time
            sl_price, ce_pe_price, intra_sl_price = calculate_sl_intra(current_entry_time, sl, intra_sl, ce_data, pe_data)
            sl_time, intra_sl_time = check_sl_hit(ce_data, pe_data, sl_price, intra_sl_price)
            print("next trade hit")

    # Create a DataFrame from the list of dictionaries
    trade_df = pd.DataFrame(trade_log)

    return {
        "total_pnl": total_pnl,
        "trade_details": trade_df
    }

# %%
nft = pd.read_pickle(future_files[0]).set_index('date_time')
opt = pd.read_pickle(option_files[0]).set_index('date_time')

date = str(nft.index[0]).split(" ")[0]
entry_time =  pd.to_datetime(f"{date} 09:20:00")
exit_time = pd.to_datetime(f"{date} 15:25:00")

sl ,intra_sl ,om=  8 , 20 , 0.1
print(om,entry_time,exit_time,sl,intra_sl)
backtest_strategy(opt,nft,om,entry_time,exit_time,sl,intra_sl)
# Out:
# 0.1 2024-01-01 09:20:00 2024-01-01 15:25:00 8 20
# sl price 59.832 ce pe price 55.4
# SL HIT :  2024-01-01 14:11:00
# pnl  -4.432000000000002
# total pnl  -4.432000000000002
# next trade hit
# SL HIT :  2024-01-01 14:42:00
# pnl  -4.936000000000007
# total pnl  -9.36800000000001
# next trade hit
# SL HIT :  2024-01-01 14:44:00
# pnl  -5.347999999999999
# total pnl  -14.716000000000008
# next trade hit
# SL HIT :  2024-01-01 14:49:00
# pnl  -5.847999999999999
# total pnl  -20.564000000000007
# next trade hit
# SL NOT HIT
# total pnl  24.73599999999999
# {'total_pnl': np.float64(24.73599999999999),
#  'trade_details':            entry_time ce_scrip pe_scrip  entry_price           exit_time  \
#  0 2024-01-01 09:20:00  22000CE  21400PE        55.40 2024-01-01 14:11:00
#  1 2024-01-01 14:11:00  22000CE  21400PE        61.70 2024-01-01 14:42:00
#  2 2024-01-01 14:42:00  22000CE  21400PE        66.85 2024-01-01 14:44:00
#  3 2024-01-01 14:44:00  22000CE  21400PE        73.10 2024-01-01 14:49:00
#  4 2024-01-01 14:49:00  22000CE  21400PE        82.00 2024-01-01 15:25:00
#
#     exit_price     pnl exit_reason
#  0      59.832  -4.432      SL Hit
#  1      66.636  -4.936      SL Hit
#  2      72.198  -5.348      SL Hit
#  3      78.948  -5.848      SL Hit
#  4      36.700  45.300   Time Exit  }

# %%
all_trades_df = pd.DataFrame()

trade_counter = 0

for nf, no in zip(future_files, option_files):
    try:
        nft = pd.read_pickle(nf).set_index('date_time')
        opt = pd.read_pickle(no).set_index('date_time')

        nft.index = pd.to_datetime(nft.index)
        opt.index = pd.to_datetime(opt.index)

        print(f"Processing file: {nf}")
        
        date = str(nft.index[0]).split(" ")[0]
        entry_time = pd.to_datetime(f"{date} 09:20:00")
        exit_time = pd.to_datetime(f"{date} 15:25:00")
        sl, intra_sl, om = 8, 20, 0.1

        # Call the backtest function and get the results
        result = backtest_strategy(opt, nft, om, entry_time, exit_time, sl, intra_sl)
        
        # Get the DataFrame of trade details from the result
        trade_details_df = result['trade_details']

        # Add a unique identifier for each day/file
        trade_details_df['file_id'] = trade_counter
        trade_counter += 1

        # Concatenate the new trades to the main DataFrame
        all_trades_df = pd.concat([all_trades_df, trade_details_df], ignore_index=True)

    except Exception as e:
        print(f"Error processing file {nf}: {e}")
        # You can log the error or just continue to the next file
        continue

# After the loop, save the master DataFrame to a single CSV file
if not all_trades_df.empty:
    all_trades_df['cumulative_pnl'] = all_trades_df['pnl'].cumsum()
    all_trades_df.to_csv('nifty/all_backtest_trades.csv', index=False)
    print("All backtest results saved to all_backtest_trades.csv")
else:
    print("No trade data was generated.")
# Out:
# Processing file: C:\PICKLE\Nifty Future\2024-01-01_nifty_future.pkl
# sl price 59.832 ce pe price 55.4
# SL HIT :  2024-01-01 14:11:00
# pnl  -4.432000000000002
# total pnl  -4.432000000000002
# next trade hit
# SL HIT :  2024-01-01 14:42:00
# pnl  -4.936000000000007
# total pnl  -9.36800000000001
# next trade hit
# SL HIT :  2024-01-01 14:44:00
# pnl  -5.347999999999999
# total pnl  -14.716000000000008
# next trade hit
# SL HIT :  2024-01-01 14:49:00
# pnl  -5.847999999999999
# total pnl  -20.564000000000007
# next trade hit
# SL NOT HIT
# total pnl  24.73599999999999
# Processing file: C:\PICKLE\Nifty Future\2024-01-02_nifty_future.pkl
# sl price 49.03200000000001 ce pe price 45.400000000000006
# SL HIT :  2024-01-02 09:58:00
# pnl  -3.632000000000005
# total pnl  -3.632000000000005
# next trade hit
# SL HIT :  2024-01-02 10:24:00
# pnl  -4.068000000000005
# total pnl  -7.70000000000001
# next trade hit
# INTRA SL HIT  20
# pnl  -11.54
# Processing file: C:\PICKLE\Nifty Future\2024-01-03_nifty_future.pkl
# sl price 61.937999999999995 ce pe price 57.349999999999994
# SL NOT HIT
# total pnl  22.499999999999993
# Processing file: C:\PICKLE\Nifty Future\2024
# sl price 53.406000000000006 ce pe price 49.45
# SL HIT :  2024-01-31 09:29:00
# pnl  -3.956000000000003
# total pnl  -3.956000000000003
# next trade hit
# SL HIT :  2024-01-31 11:05:00
# pnl  -4.3160000000000025
# total pnl  -8.272000000000006
# next trade hit
# SL HIT :  2024-01-31 11:08:00
# pnl  -4.6640000000000015
# total pnl  -12.936000000000007
# next trade hit
# SL HIT :  2024-01-31 11:30:00
# pnl  -5.076000000000008
# total pnl  -18.012000000000015
# next trade hit
# SL HIT :  2024-01-31 11:33:00
# pnl  -5.591999999999999
# total pnl  -23.604000000000013
# next trade hit
# SL NOT HIT
# total pnl  -21.15400000000001
# Processing file: C:\PICKLE\Nifty Future\2024-02-01_nifty_future.pkl
# sl price 61.236000000000004 ce pe price 56.7
# SL NOT HIT
# total pnl  56.6
# Processing file: C:\PICKLE\Nifty Future\2024-02-02_nifty_future.pkl
# sl price 54.75600000000001 ce pe price 50.7
# SL HIT :  2024-02-02 11:30:00
# pnl  -4.0560000000000045
# total pnl  -4.0560000000000045
# next trade hit
# SL HIT :  2024-02-02 11:37:00
# pnl  -4.568000000000005
# total pnl  -8.62400000000001
# next trade hit
# SL HIT :  2024-02-02 11:40:00
# pnl  -5.044000000000011
# total pnl  -13.66800000000002
# next trade hit
# SL NOT HIT
# total pnl  22.581999999999972
# Processing file: C:\PICKLE\Nifty Future\2024-02-05_nifty_future.pkl
# sl price 54.21600000000001 ce pe price 50.2
# SL HIT :  2024-02-05 09:26:00
# pnl  -4.016000000000005
# total pnl  -4.016000000000005
# next trade hit
# SL HIT :  2024-02-05 09:52:00
# pnl  -4.648000000000003
# total pnl  -8.664000000000009
# next trade hit
# SL NOT HIT
# total pnl  14.985999999999997
# Processing file: C:\PICKLE\Nifty Future\2024-02-06_nifty_future.pkl
# sl price 63.18000000000001 ce pe price 58.5
# SL HIT :  2024-02-06 09:49:00
# pnl  -4.680000000000007
# total pnl  -4.680000000000007
# next trade hit
# SL NOT HIT
# total pnl  -2.780000000000001
# Processing file: C:\PICKLE\Nifty Future\2024-02-07_nifty_future.pkl
# sl price 60.642 ce pe price 56.15
# SL HIT :  2024-02-07 11:40:00
# pnl  -4.492000000000004
# total pnl  -4.492000000000004
# next trade hit
# SL NOT HIT
# total pnl  37.108
# Processing file: C:\PICKLE\Nifty Future\2024-02-08_nifty_future.pkl
# sl price 52.27200000000001 ce pe price 48.400000000000006
# INTRA SL HIT  20
# pnl  -9.68
# Processing file: C:\PICKLE\Nifty Future\2024-02-09_nifty_future.pkl
# sl price 50.65200000000001 ce pe price 46.900000000000006
# SL HIT :  2024-02-09 09:28:00
# pnl  -3.7520000000000024
# total pnl  -3.7520000000000024
# next trade hit
# SL NOT HIT
# total pnl  18.748
# Processing file: C:\PICKLE\Nifty Future\2024-02-12_nifty_future.pkl
# sl price 66.528 ce pe price 61.6
# SL HIT :  2024-02-12 12:07:00
# pnl  -4.928000000000004
# total pnl  -4.928000000000004
# next trade hit
# SL HIT :  2024-02-12 12:57:00
# pnl  -5.544000000000011
# total pnl  -10.472000000000016
# next trade hit
999999993
# Processing file: C:\PICKLE\Nifty Future\2024-04-05_nifty_future.pkl
# sl price 62.1 ce pe price 57.5
# SL HIT :  2024-04-05 09:25:00
# pnl  -4.600000000000001
# total pnl  -4.600000000000001
# next trade hit
# SL NOT HIT
# total pnl  10.950000000000003
# Processing file: C:\PICKLE\Nifty Future\2024-04-08_nifty_future.pkl
# sl price 49.517999999999994 ce pe price 45.849999999999994
# SL HIT :  2024-04-08 09:38:00
# pnl  -3.6679999999999993
# total pnl  -3.6679999999999993
# next trade hit
# SL HIT :  2024-04-08 13:04:00
# pnl  -4.148000000000003
# total pnl  -7.8160000000000025
# next trade hit
# SL NOT HIT
# total pnl  4.1839999999999975
# Processing file: C:\PICKLE\Nifty Future\2024-04-09_nifty_future.pkl
# sl price 51.894 ce pe price 48.05
# SL NOT HIT
# total pnl  22.099999999999994
# Processing file: C:\PICKLE\Nifty Future\2024-04-10_nifty_future.pkl
# sl price 58.050000000000004 ce pe price 53.75
# SL NOT HIT
# total pnl  49.65
# Processing file: C:\PICKLE\Nifty Future\2024-04-12_nifty_future.pkl
# sl price 60.156000000000006 ce pe price 55.7
# SL NOT HIT
# total pnl  3.75
# Processing file: C:\PICKLE\Nifty Future\2024-04-15_nifty_future.pkl
# sl price 55.620000000000005 ce pe price 51.5
# SL NOT HIT
# total pnl  17.700000000000003
# Processing file: C:\PICKLE\Nifty Future\2024-04-16_nifty_future.pkl
# sl price 58.644 ce pe price 54.3
# SL NOT HIT
# total pnl  21.049999999999997
# Processing file: C:\PICKLE\Nifty Future\2024-04-18_nifty_future.pkl
# sl price 54.0 ce pe price 50.0
# INTRA SL HIT  20
# pnl  -10.0
# Processing file: C:\PICKLE\Nifty Future\2024-04-19_nifty_future.pkl
# sl price 57.45600000000001 ce pe price 53.2
# SL HIT :  2024-04-19 12:22:00
# pnl  -4.256000000000007
# total pnl  -4.256000000000007
# next trade hit
# SL HIT :  2024-04-19 12:26:00
# pnl  -4.636000000000003
# total pnl  -8.89200000000001
# next trade hit
# SL HIT :  2024-04-19 12:38:00
# pnl  -5.02000000000001
# total pnl  -13.91200000000002
# next trade hit
# SL HIT :  2024-04-19 12:43:00
# pnl  -5.436000000000007
# total pnl  -19.348000000000027
# next trade hit
# SL HIT :  2024-04-19 13:06:00
# pnl  -5.896000000000001
# total pnl  -25.244000000000028
# next trade hit
# SL HIT :  2024-04-19 13:50:00
# pnl  -6.388000000000005
# total pnl  -31.632000000000033
# next trade hit
# SL HIT :  2024-04-19 13:56:00
# pnl  -6.932000000000002
# total pnl  -38.564000000000036
# next trade hit
# SL HIT :  2024-04-19 14:08:00
# pnl  -7.740000000000009
# total pnl  -46.304000000000045
# next trade hit
# SL NOT HIT
# total pnl  -23.954000000000036
# Processing file: C:\PICKLE\Nifty Future\2024-04-22_nifty_future.pkl
# sl price 54.648 ce pe price 50.6
# SL HIT :  2024-04-22 09:29:00
# pnl  -4.048000000000002
# total pnl  -4.048000000000002
# next trade hit
# SL NOT HIT
# total pnl  -2.548000000000009
# Processing file: C:\PICKLE\Nifty Future\2024-04-23_nifty_future.pkl
# sl price 54.054 ce pe price 50.05
# SL NOT HIT
# total pnl  17.949999999999996
# Processing file: C:\PICKLE\Nifty Future\2024-04-24_nifty_future.pkl
# sl price 54.75600000000001 ce pe price 50.7
# SL HIT :  2024-04-24 10:41:00
# pnl  -4.0560000000000045
# total pnl  -4.0560000000000045
# next trade hit
# SL NOT HIT
# total pnl  25.993999999999993
# Processing file: C:\PICKLE\Nifty Future\2024
# pnl  -4.656000000000006
# total pnl  -8.824000000000012
# next trade hit
# SL NOT HIT
# total pnl  17.025999999999982
# Processing file: C:\PICKLE\Nifty Future\2024-05-07_nifty_future.pkl
# sl price 63.34200000000001 ce pe price 58.650000000000006
# SL HIT :  2024-05-07 10:34:00
# pnl  -4.692000000000007
# total pnl  -4.692000000000007
# next trade hit
# SL HIT :  2024-05-07 10:52:00
# pnl  -5.13600000000001
# total pnl  -9.828000000000017
# next trade hit
# SL HIT :  2024-05-07 11:23:00
# pnl  -5.564000000000007
# total pnl  -15.392000000000024
# next trade hit
# SL HIT :  2024-05-07 11:26:00
# pnl  -6.016000000000005
# total pnl  -21.40800000000003
# next trade hit
# SL HIT :  2024-05-07 11:37:00
# pnl  -6.532000000000011
# total pnl  -27.94000000000004
# next trade hit
# SL NOT HIT
# total pnl  9.209999999999958
# Processing file: C:\PICKLE\Nifty Future\2024-05-08_nifty_future.pkl
# sl price 55.727999999999994 ce pe price 51.599999999999994
# SL HIT :  2024-05-08 12:21:00
# pnl  -4.128
# total pnl  -4.128
# next trade hit
# SL NOT HIT
# total pnl  32.821999999999996
# Processing file: C:\PICKLE\Nifty Future\2024-05-09_nifty_future.pkl
# sl price 59.67 ce pe price 55.25
# SL HIT :  2024-05-09 09:25:00
# pnl  -4.420000000000002
# total pnl  -4.420000000000002
# next trade hit
# SL HIT :  2024-05-09 09:29:00
# pnl  -4.784000000000006
# total pnl  -9.204000000000008
# next trade hit
# SL HIT :  2024-05-09 10:12:00
# pnl  -5.300000000000011
# total pnl  -14.504000000000019
# next trade hit
# SL HIT :  2024-05-09 10:25:00
# pnl  -5.916000000000011
# total pnl  -20.42000000000003
# next trade hit
# INTRA SL HIT  20
# pnl  -16.629999999999995
# Processing file: C:\PICKLE\Nifty Future\2024-05-10_nifty_future.pkl
# sl price 51.138000000000005 ce pe price 47.35
# SL HIT :  2024-05-10 09:54:00
# pnl  -3.788000000000004
# total pnl  -3.788000000000004
# next trade hit
# SL NOT HIT
# total pnl  18.561999999999998
# Processing file: C:\PICKLE\Nifty Future\2024-05-13_nifty_future.pkl
# sl price 66.96000000000001 ce pe price 62.0
# SL NOT HIT
# total pnl  14.599999999999994
# Processing file: C:\PICKLE\Nifty Future\2024-05-14_nifty_future.pkl
# sl price 66.15 ce pe price 61.25
# SL HIT :  2024-05-14 09:28:00
# pnl  -4.900000000000006
# total pnl  -4.900000000000006
# next trade hit
# SL NOT HIT
# total pnl  18.85
# Processing file: C:\PICKLE\Nifty Future\2024-05-15_nifty_future.pkl
# sl price 48.708000000000006 ce pe price 45.1
# SL HIT :  2024-05-15 10:07:00
# pnl  -3.608000000000004
# total pnl  -3.608000000000004
# next trade hit
# SL HIT :  2024-05-15 10:08:00
# pnl  -4.020000000000003
# total pnl  -7.628000000000007
# next trade hit
# SL NOT HIT
# total pnl  26.722
# Processing file: C:\PICKLE\Nifty Future\2024-05-16_nifty_future.pkl
# sl price 67.662 ce pe price 62.65
# SL HIT :  2024-05-16 09:21:00
# pnl  -5.012000000000008
# total pnl  -5.012000000000008
# next trade hit
# SL HIT :  2024-05-16 09:32:00
# pnl  -5.4879999999999995
# total pnl  -10.500000000000007
# next trade hit
# INTRA SL HIT  20
# pnl  -15.090000000000003
# Processing file: C:\PICKLE\Nifty Future\2024-05-17_nifty_future.pkl
# sl price 54.324 ce pe price 50.3
# SL NOT HIT
# total pnl  17.200000000000003
# Processing file: C:\PICKLE\Nifty Future\2024-05-21_nifty_future.pkl
# sl price 65.664 ce pe price 60.8
# SL NOT HIT
# total pnl  22.5
# Processing file: C:\PICKLE\Nifty Future\2024-05-22_nifty_future.pkl
# sl price 72.63000000000001 ce pe price 67.25
# SL HIT :  2024-05-22 09:45:00
# pnl  -5.38000000000001
# total pnl  -5.38000000000001
# next trade hit
# SL NOT HIT
# total pnl  21.669999999999987
# Processing file: C:\PICKLE\Nifty Future\2024-05-23_nifty_future.pkl
# sl price 64.53 ce pe price 59.75
# SL HIT :  2024-05-23 09:28:00
# pnl  -4.780000000000001
# total pnl  -4.780000000000001
# next trade hit
# SL HIT :  2024-05-23 09:34:00
# pnl  -5.212000000000003
# total pnl  -9.992000000000004
# next trade hit
# SL HIT :  2024-05-23 09:36:00
# pnl  -5.684000000000012
# total pnl  -15.676000000000016
# next trade hit
# SL HIT :  2024-05-23 09:40:00
# pnl  -6.140000000000001
# total pnl  -21.816000000000017
# next trade hit
# SL HIT :  2024-05-23 10:21:00
# pnl  -7.216000000000008
# total pnl  -29.032000000000025
# next trade hit
# INTRA SL HIT  20
# pnl  -19.529999999999987
# Processing file: C:\PICKLE\Nifty Future\2024-05-24_nifty_future.pkl
# sl price 64.26 ce pe price 59.5
# SL HIT :  2024-05-24 09:31:00
# pnl  -4.760000000000005
# total pnl  -4.760000000000005
# next trade hit
# SL NOT HIT
# total pnl  22.739999999999995
# Processing file: C:\PICKLE\Nifty Future\2024-05-27_nifty_future.pkl
# sl price 61.614000000000004 ce pe price 57.05
# SL HIT :  2024-05-27 12:25:00
# pnl  -4.564000000000007
# total pnl  -4.564000000000007
# next trade hit
# SL NOT HIT
# total pnl  13.685999999999993
# Processing file: C:\PICKLE\Nifty Future\2024-05-28_nifty_future.pkl
# sl price 59.184 ce pe price 54.8
# SL NOT HIT
# total pnl  20.199999999999996
# Processing file: C:\PICKLE\Nifty Future\2024-05-29_nifty_future.pkl
# sl price 59.507999999999996 ce pe price 55.099999999999994
# SL NOT HIT
# total pnl  22.249999999999993
# Processing file: C:\PICKLE\Nifty Future\2024-05-30_nifty_future.pkl
# sl price 58.968 ce pe price 54.6
# SL HIT :  2024-05-30 09:28:00
# pnl  -4.368000000000002
# total pnl  -4.368000000000002
# next trade hit
# SL HIT :  2024-05-30 14:58:00
# pnl  -4.7719999999999985
# total pnl  -9.14
# next trade hit
# INTRA SL HIT  20
# pnl  -13.319999999999993
# Processing file: C:\PICKLE\Nifty Future\2024-05-31_nifty_future.pkl
# sl price 54.540000000000006 ce pe price 50.5
# SL HIT :  2024-05-31 10:00:00
# pnl  -4.040000000000006
# total pnl  -4.040000000000006
# next trade hit
# SL HIT :  2024-05-31 14:15:00
# pnl  -4.440000000000005
# total pnl  -8.480000000000011
# next trade hit
# SL NOT HIT
# total pnl  -8.480000000000011
# Processing file: C:\PICKLE\Nifty Future\2024-06-03_nifty_future.pkl
# sl price 72.25200000000001 ce pe price 66.9
# INTRA SL HIT  20
# pnl  -13.379999999999995
# Processing file: C:\PICKLE\Nifty Future\2024-06-04_nifty_future.pkl
# sl price 67.01400000000001 ce pe price 62.050000000000004
# SL HIT :  2024-06-04 09:21:00
# pnl  -4.964000000000006
# total pnl  -4.964000000000006
# next trade hit
# SL HIT :  2024-06-04 09:22:00
# pnl  -5.416000000000011
# total pnl  -10.380000000000017
# next trade hit
# INTRA SL HIT  20
# pnl  -15.36
# Processing file: C:\PICKLE\Nifty Future\2024-06-05_nifty_future.pkl
# sl price 48.330000000000005 ce pe price 44.75
# SL HIT :  2024-06-05 11:09:00
# pnl  -3.5800000000000054
# total pnl  -3.5800000000000054
# next trade hit
# SL HIT :  2024-06-05 11:10:00
# pnl  -4.072000000000003
# total pnl  -7.652000000000008
# next trade hit
# INTRA SL HIT  20
# pnl  -12.18
# Processing file: C:\PICKLE\Nifty Future\2024-06-06_nifty_future.pkl
# sl price 56.64600000000001 ce pe price 52.45
# SL NOT HIT
# total pnl  28.85
# Processing file: C:\PICKLE\Nifty Future\2024-06-07_nifty_future.pkl
# sl price 54.162 ce pe price 50.15
# SL HIT :  2024-06-07 09:22:00
# pnl  -4.0120000000000005
# total pnl  -4.0120000000000005
# next trade hit
# SL HIT :  2024-06-07 11:36:00
# pnl  -4.668000000000006
# total pnl  -8.680000000000007
# next trade hit
# SL HIT :  2024-06-07 11:46:00
# pnl  -5.076000000000008
# total pnl  -13.756000000000014
# next trade hit
# SL HIT :  2024-06-07 11:50:00
# pnl  -5.588000000000008
# total pnl  -19.344000000000023
# next trade hit
# INTRA SL HIT  20
# pnl  -15.989999999999995
# Processing file: C:\PICKLE\Nifty Future\2024-06-10_nifty_future.pkl
# sl price 58.53600000000001 ce pe price 54.2
# SL NOT HIT
# total pnl  24.75
# Processing file: C:\PICKLE\Nifty Future\2024-06-11_nifty_future.pkl
# sl price 67.176 ce pe price 62.2
# SL NOT HIT
# total pnl  39.75
# Processing file: C:\PICKLE\Nifty Future\2024-06-12_nifty_future.pkl
# sl price 67.338 ce pe price 62.349999999999994
# SL HIT :  2024-06-12 09:40:00
# pnl  -4.9879999999999995
# total pnl  -4.9879999999999995
# next trade hit
# SL HIT :  2024-06-12 09:57:00
# pnl  -5.76400000000001
# total pnl  -10.75200000000001
# next trade hit
# SL HIT :  2024-06-12 10:03:00
# pnl  -6.272000000000006
# total pnl  -17.024000000000015
# next trade hit
# SL NOT HIT
# total pnl  23.975999999999985
# Processing file: C:\PICKLE\Nifty Future\2024-06-13_nifty_future.pkl
# sl price 71.658 ce pe price 66.35
# SL NOT HIT
# total pnl  66.25
# Processing file: C:\PICKLE\Nifty Future\2024-06-14_nifty_future.pkl
# sl price 68.31 ce pe price 63.25
# SL HIT :  2024-06-14 09:23:00
# pnl  -5.060000000000002
# total pnl  -5.060000000000002
# next trade hit
# SL NOT HIT
# total pnl  17.939999999999984
# Processing file: C:\PICKLE\Nifty Future\2024-06-18_nifty_future.pkl
# sl price 56.05200000000001 ce pe price 51.900000000000006
# SL NOT HIT
# total pnl  12.550000000000004
# Processing file: C:\PICKLE\Nifty Future\2024-06-19_nifty_future.pkl
# sl price 72.30600000000001 ce pe price 66.95
# SL HIT :  2024-06-19 09:30:00
# pnl  -5.356000000000009
# pnl  -6.140000000000001
# total pnl  -11.688000000000002
# next trade hit
# INTRA SL HIT  20
# pnl  -17.189999999999998
# Processing file: C:\PICKLE\Nifty Future\2024-06-28_nifty_future.pkl
# sl price 59.61600000000001 ce pe price 55.2
# SL HIT :  2024-06-28 09:38:00
# pnl  -4.416000000000004
# total pnl  -4.416000000000004
# next trade hit
# SL HIT :  2024-06-28 09:41:00
# pnl  -4.996000000000002
# total pnl  -9.412000000000006
# next trade hit
# SL NOT HIT
# total pnl  19.537999999999997
# Processing file: C:\PICKLE\Nifty Future\2024-07-01_nifty_future.pkl
# sl price 73.60200000000002 ce pe price 68.15
# SL HIT :  2024-07-01 09:25:00
# pnl  -5.452000000000012
# total pnl  -5.452000000000012
# next trade hit
# SL NOT HIT
# total pnl  5.4979999999999905
# Processing file: C:\PICKLE\Nifty Future\2024-07-02_nifty_future.pkl
# sl price 54.81 ce pe price 50.75
# SL HIT :  2024-07-02 09:37:00
# pnl  -4.060000000000002
# total pnl  -4.060000000000002
# next trade hit
# SL HIT :  2024-07-02 09:45:00
# pnl  -4.400000000000006
# total pnl  -8.460000000000008
# next trade hit
# SL NOT HIT
# total pnl  18.239999999999988
# Processing file: C:\PICKLE\Nifty Future\2024-07-03_nifty_future.pkl
# sl price 55.29600000000001 ce pe price 51.2
# SL HIT :  2024-07-03 09:21:00
# pnl  -4.096000000000004
# total pnl  -4.096000000000004
# next trade hit
# SL HIT :  2024-07-03 09:44:00
# pnl  -4.584000000000003
# total pnl  -8.680000000000007
# next trade hit
# SL HIT :  2024-07-03 09:49:00
# pnl  -5.084000000000003
# total pnl  -13.76400000000001
# next trade hit
# SL NOT HIT
# total pnl  15.385999999999996
# Processing file: C:\PICKLE\Nifty Future\2024-07-04_nifty_future.pkl
# sl price 66.04200000000002 ce pe price 61.150000000000006
# SL NOT HIT
# total pnl  61.00000000000001
# Processing file: C:\PICKLE\Nifty Future\2024-07-05_nifty_future.pkl
# sl price 55.620000000000005 ce pe price 51.5
# SL HIT :  2024-07-05 11:40:00
# pnl  -4.1200000000000045
# total pnl  -4.1200000000000045
# next trade hit
# SL NOT HIT
# total pnl  4.1299999999999955
# Processing file: C:\PICKLE\Nifty Future\2024-07-08_nifty_future.pkl
# sl price 68.85000000000001 ce pe price 63.75
# SL NOT HIT
# total pnl  13.75
# Processing file: C:\PICKLE\Nifty Future\2024-07-09_nifty_future.pkl
# sl price 61.992000000000004 ce pe price 57.4
# SL NOT HIT
# total pnl  7.350000000000001
# Processing file: C:\PICKLE\Nifty Future\2024-07-10_nifty_future.pkl
# sl price 61.236000000000004 ce pe price 56.7
# INTRA SL HIT  20
# pnl  -11.340000000000003
# Processing file: C:\PICKLE\Nifty Future\2024-07-11_nifty_future.pkl
# sl price 67.014 ce pe price 62.05
# INTRA SL HIT  20
# pnl  -12.409999999999997
# Processing file: C:\PICKLE\Nifty Future\2024-07-12_nifty_future.pkl
# sl price 66.42 ce pe price 61.5
# SL HIT :  2024-07-12 09:26:00
# pnl  -4.920000000000002
# total pnl  -4.920000000000002
# next trade hit
# INTRA SL HIT  20
# pnl  -13.840000000000003
# Processing file: C:\PICKLE\Nifty Future\2024-07-15_nifty_future.pkl
# sl price 59.56200000000001 ce pe price 55.150000000000006
# SL NOT HIT
# total pnl  14.400000000000006
# Processing file: C:\PICKLE\Nifty Future\2024-07-16_nifty_future.pkl
# sl price 78.73200000000001 ce pe price 72.9
# SL NOT HIT
# total pnl  36.050000000000004
# Processing file: C:\PICKLE\Nifty Future\2024-07-18_nifty_future.pkl
# sl price 70.41600000000001 ce pe price 65.2
# SL HIT :  2024-07-18 09:47:00
# pnl  -5.216000000000008
# total pnl  -5.216000000000008
# next trade hit
# INTRA SL HIT  20
# pnl  -15.810000000000002
# Processing file: C:\PICKLE\Nifty Future\2024-07-19_nifty_future.pkl
# sl price 61.290000000000006 ce pe price 56.75
# SL HIT :  2024-07-19 14:55:00
# pnl  -4.540000000000006
# total pnl  -4.540000000000006
# next trade hit
# SL NOT HIT
# total pnl  -3.3400000000000105
# Processing file: C:\PICKLE\Nifty Future\2024-07-22_nifty_future.pkl
# sl price 54.81 ce pe price 50.75
# SL HIT :  2024-07-22 09:27:00
# pnl  -4.060000000000002
# total pnl  -4.060000000000002
# next trade hit
# SL NOT HIT
# total pnl  -4.409999999999997
# Processing file: C:\PICKLE\Nifty Future\2024-07-23_nifty_future.pkl
# sl price 62.964 ce pe price 58.3
# SL HIT :  2024-07-23 09:24:00
# pnl  -4.6640000000000015
# total pnl  -4.6640000000000015
# next trade hit
# SL HIT :  2024-07-23 09:31:00
# pnl  -5.084000000000003
# total pnl  -9.748000000000005
# next trade hit
# SL HIT :  2024-07-23 09:43:00
# pnl  -5.544000000000011
# total pnl  -15.292000000000016
# next trade hit
# SL HIT :  2024-07-23 12:23:00
# pnl  -6.036000000000001
# total pnl  -21.328000000000017
# next trade hit
# SL NOT HIT
# total pnl  52.37199999999997
# Processing file: C:\PICKLE\Nifty Future\2024-07-24_nifty_future.pkl
# sl price 61.074 ce pe price 56.55
# SL HIT :  2024-07-24 09:39:00
# pnl  -4.524000000000001
# total pnl  -4.524000000000001
# next trade hit
# SL HIT :  2024-07-24 12:16:00
# pnl  -5.308000000000007
# total pnl  -9.832000000000008
# next trade hit
# SL HIT :  2024-07-24 12:17:00
# pnl  -5.7960000000000065
# total pnl  -15.628000000000014
# next trade hit
# SL HIT :  2024-07-24 12:20:00
# pnl  -6.344000000000008
# total pnl  -21.972000000000023
# next trade hit
# SL NOT HIT
# total pnl  40.47799999999998
# Processing file: C:\PICKLE\Nifty Future\2024-07-25_nifty_future.pkl
# sl price 76.626 ce pe price 70.95
# SL HIT :  2024-07-25 12:14:00
# pnl  -5.676000000000002
# total pnl  -5.676000000000002
# next trade hit
# SL HIT :  2024-07-25 12:20:00
# pnl  -6.14800000000001
# total pnl  -11.824000000000012
# next trade hit
# SL HIT :  2024-07-25 12:48:00
# pnl  -6.760000000000005
# total pnl  -18.584000000000017
# next trade hit
# SL HIT :  2024-07-25 12:51:00
# pnl  -7.440000000000012
# total pnl  -26.02400000000003
# next trade hit
# INTRA SL HIT  20
# pnl  -20.129999999999995
# Processing file: C:\PICKLE\Nifty Future\2024-07-26_nifty_future.pkl
# sl price 63.072 ce pe price 58.4
# SL HIT :  2024-07-26 09:40:00
# pnl  -4.672000000000004
# total pnl  -4.672000000000004
# next trade hit
# ...
# Processing file: C:\PICKLE\Nifty Future\2024-10-25_nifty_future.pkl
# sl price 55.026 ce pe price 50.95
# SL HIT :  2024-10-25 09:40:00
# pnl  -4.0760000000000005
# total pnl  -4.0760000000000005
# next trade hit
# SL HIT :  2024-10-25 09:49:00
# pnl  -4.436000000000007
# total pnl  -8.512000000000008
# next trade hit
# SL HIT :  2024-10-25 09:58:00
# pnl  -4.800000000000011
# total pnl  -13.312000000000019
# next trade hit
# SL HIT :  2024-10-25 10:47:00
# pnl  -5.424000000000007
# total pnl  -18.736000000000026
# next trade hit
# INTRA SL HIT  20
# pnl  -14.909999999999997
# Processing file: C:\PICKLE\Nifty Future\2024-10-28_nifty_future.pkl
# sl price 69.39 ce pe price 64.25
# SL HIT :  2024-10-28 09:30:00
# pnl  -5.140000000000001
# total pnl  -5.140000000000001
# next trade hit
# SL HIT :  2024-10-28 10:36:00
# pnl  -6.004000000000005
# total pnl  -11.144000000000005
# next trade hit
# SL HIT :  2024-10-28 12:13:00
# pnl  -6.50800000000001
# total pnl  -17.652000000000015
# next trade hit
# SL NOT HIT
# total pnl  30.647999999999975
# Processing file: C:\PICKLE\Nifty Future\2024-10-29_nifty_future.pkl
# sl price 64.69200000000001 ce pe price 59.9
# SL HIT :  2024-10-29 09:35:00
# pnl  -4.792000000000009
# total pnl  -4.792000000000009
# next trade hit
# SL HIT :  2024-10-29 09:48:00
# pnl  -5.288000000000011
# total pnl  -10.08000000000002
# next trade hit
# SL HIT :  2024-10-29 10:07:00
# pnl  -5.812000000000012
# total pnl  -15.892000000000031
# next trade hit
# SL NOT HIT
# total pnl  -1.9420000000000428
# Processing file: C:\PICKLE\Nifty Future\2024-10-30_nifty_future.pkl
# sl price 68.742 ce pe price 63.650000000000006
# SL HIT :  2024-10-30 09:22:00
# pnl  -5.091999999999999
# total pnl  -5.091999999999999
# next trade hit
# SL NOT HIT
# total pnl  34.358000000000004
# Processing file: C:\PICKLE\Nifty Future\2024-10-31_nifty_future.pkl
# sl price 53.67600000000001 ce pe price 49.7
# SL NOT HIT
# total pnl  49.5
# Processing file: C:\PICKLE\Nifty Future\2024-11-04_nifty_future.pkl
# sl price 57.99600000000001 ce pe price 53.7
# SL HIT :  2024-11-04 09:46:00
# pnl  -4.2960000000000065
# total pnl  -4.2960000000000065
# next trade hit
# SL HIT :  2024-11-04 10:12:00
# pnl  -4.668000000000006
# total pnl  -8.964000000000013
# next trade hit
# SL HIT :  2024-11-04 10:57:00
# pnl  -5.492000000000004
# total pnl  -14.456000000000017
# next trade hit
# SL HIT :  2024-11-04 11:01:00
# pnl  -6.180000000000007
# total pnl  -20.636000000000024
# next trade hit
# SL HIT :  2024-11-04 11:08:00
# pnl  -7.004000000000005
# total pnl  -27.64000000000003
# next trade hit
# SL NOT HIT
# total pnl  24.109999999999978
# Processing file: C:\PICKLE\Nifty Future\2024-11-05_nifty_future.pkl
# sl price 57.672000000000004 ce pe price 53.4
# SL NOT HIT
# total pnl  0.04999999999999716
# Processing file: C:\PICKLE\Nifty Future\2024-11-06_nifty_future.pkl
# pnl  -4.632000000000005
# total pnl  -4.632000000000005
# next trade hit
# SL HIT :  2024-11-13 14:29:00
# pnl  -5.207999999999998
# total pnl  -9.840000000000003
# next trade hit
# SL HIT :  2024-11-13 14:30:00
# pnl  -6.02000000000001
# total pnl  -15.860000000000014
# next trade hit
# SL HIT :  2024-11-13 14:36:00
# pnl  -6.50800000000001
# total pnl  -22.368000000000023
# next trade hit
# SL HIT :  2024-11-13 14:41:00
# pnl  -7.096000000000004
# total pnl  -29.464000000000027
# next trade hit
# SL HIT :  2024-11-13 15:05:00
# pnl  -8.120000000000005
# total pnl  -37.58400000000003
# next trade hit
# SL NOT HIT
# total pnl  13.715999999999966
# Processing file: C:\PICKLE\Nifty Future\2024-11-14_nifty_future.pkl
# sl price 63.45 ce pe price 58.75
# SL NOT HIT
# total pnl  58.65
# Processing file: C:\PICKLE\Nifty Future\2024-11-18_nifty_future.pkl
# sl price 66.96000000000001 ce pe price 62.0
# SL NOT HIT
# total pnl  28.6
# Processing file: C:\PICKLE\Nifty Future\2024-11-19_nifty_future.pkl
# sl price 52.86600000000001 ce pe price 48.95
# INTRA SL HIT  20
# pnl  -9.79
# Processing file: C:\PICKLE\Nifty Future\2024-11-21_nifty_future.pkl
# sl price 52.86600000000001 ce pe price 48.95
# SL NOT HIT
# total pnl  48.85
# Processing file: C:\PICKLE\Nifty Future\2024-11-22_nifty_future.pkl
# sl price 60.804 ce pe price 56.3
# SL HIT :  2024-11-22 09:22:00
# pnl  -4.504000000000005
# total pnl  -4.504000000000005
# next trade hit
# SL HIT :  2024-11-22 09:28:00
# pnl  -5.116
# total pnl  -9.620000000000005
# next trade hit
# SL HIT :  2024-11-22 10:03:00
# pnl  -5.572000000000003
# total pnl  -15.192000000000007
# next trade hit
# SL HIT :  2024-11-22 10:07:00
# pnl  -6.532000000000011
# total pnl  -21.724000000000018
# next trade hit
# SL HIT :  2024-11-22 11:54:00
# pnl  -7.064000000000007
# total pnl  -28.788000000000025
# next trade hit
# SL HIT :  2024-11-22 12:05:00
# pnl  -7.768000000000001
# total pnl  -36.556000000000026
# next trade hit
# SL HIT :  2024-11-22 12:06:00
# pnl  -8.640000000000015
# total pnl  -45.19600000000004
# next trade hit
# SL HIT :  2024-11-22 12:41:00
# pnl  -9.640000000000015
# total pnl  -54.836000000000055
# next trade hit
# SL HIT :  2024-11-22 13:12:00
# pnl  -11.052000000000021
# total pnl  -65.88800000000008
# next trade hit
# SL HIT :  2024-11-22 13:59:00
# pnl  -12.128000000000014
# total pnl  -78.01600000000009
# next trade hit
# SL HIT :  2024-11-22 14:00:00
# pnl  -14.308000000000021
# total pnl  -92.32400000000011
# next trade hit
# SL HIT :  2024-11-22 14:07:00
# pnl  -15.572000000000003
# total pnl  -107.89600000000011
# next trade hit
# SL HIT :  2024-11-22 14:09:00
# pnl  -16.98400000000001
# total pnl  -124.88000000000012
# next trade hit
# SL HIT :  2024-11-22 14:52:00
# pnl  -18.400000000000006
# total pnl  -143.28000000000014
# next trade hit
# SL NOT HIT
# total pnl  -86.48000000000016
# Processing file: C:\PICKLE\Nifty Future\2024-11-25_nifty_future.pkl
# sl price 52.758 ce pe price 48.85
# SL NOT HIT
# total pnl  22.400000000000002
# Processing file: C:\PICKLE\Nifty Future\2024-11-26_nifty_future.pkl
# sl price 66.63600000000001 ce pe price 61.7
# SL HIT :  2024-11-26 09:22:00
# pnl  -4.936000000000007
# total pnl  -4.936000000000007
# next trade hit
# SL NOT HIT
# total pnl  21.663999999999987
# Processing file: C:\PICKLE\Nifty Future\2024-11-27_nifty_future.pkl
# sl price 70.30799999999999 ce pe price 65.1
# SL HIT :  2024-11-27 13:43:00
# pnl  -5.207999999999998
# total pnl  -5.207999999999998
# next trade hit
# INTRA SL HIT  20
# pnl  -14.459999999999994
# Processing file: C:\PICKLE\Nifty Future\2024-11-28_nifty_future.pkl
# sl price 65.178 ce pe price 60.349999999999994
# SL HIT :  2024-11-28 09:25:00
# pnl  -4.828000000000003
# total pnl  -4.828000000000003
# next trade hit
# INTRA SL HIT  20
# pnl  -13.310000000000002
# Processing file: C:\PICKLE\Nifty Future\2024-11-29_nifty_future.pkl
# sl price 61.02 ce pe price 56.5
# SL HIT :  2024-11-29 09:27:00
# pnl  -4.520000000000003
# total pnl  -4.520000000000003
# next trade hit
# SL HIT :  2024-11-29 09:41:00
# pnl  -5.0
# total pnl  -9.520000000000003
# next trade hit
# SL HIT :  2024-11-29 10:51:00
# pnl  -5.5
# total pnl  -15.020000000000003
# next trade hit
# SL NOT HIT
# total pnl  19.43
# Processing file: C:\PICKLE\Nifty Future\2024-12-02_nifty_future.pkl
# sl price 57.564 ce pe price 53.3
# SL HIT :  2024-12-02 09:40:00
# pnl  -4.264000000000003
# total pnl  -4.264000000000003
# next trade hit
# SL HIT :  2024-12-02 10:15:00
# pnl  -4.872
# total pnl  -9.136000000000003
# next trade hit
# SL HIT :  2024-12-02 12:24:00
# pnl  -5.368000000000009
# total pnl  -14.504000000000012
# next trade hit
# SL HIT :  2024-12-02 12:28:00
# pnl  -5.856000000000009
# total pnl  -20.36000000000002
# next trade hit
# SL HIT :  2024-12-02 12:29:00
# pnl  -6.356000000000009
# total pnl  -26.71600000000003
# next trade hit
# SL HIT :  2024-12-02 13:58:00
# pnl  -6.912000000000006
# total pnl  -33.628000000000036
# next trade hit
# SL HIT :  2024-12-02 14:01:00
# pnl  -7.800000000000011
# total pnl  -41.42800000000005
# next trade hit
# SL HIT :  2024-12-02 14:17:00
# pnl  -8.444000000000003
# total pnl  -49.87200000000005
# next trade hit
# SL NOT HIT
# total pnl  -32.62200000000005
# Processing file: C:\PICKLE\Nifty Future\2024-12-03_nifty_future.pkl
# sl price 73.818 ce pe price 68.35
# SL NOT HIT
# total pnl  8.799999999999997
# Processing file: C:\PICKLE\Nifty Future\2024-12-04_nifty_future.pkl
# sl price 71.49600000000001 ce pe price 66.2
# SL HIT :  2024-12-04 11:57:00
# pnl  -5.2960000000000065
# total pnl  -5.2960000000000065
# next trade hit
# SL NOT HIT
# total pnl  15.90399999999999
# Processing file: C:\PICKLE\Nifty Future\2024-12-05_nifty_future.pkl
# sl price 74.412 ce pe price 68.9
# SL HIT :  2024-12-05 09:21:00
# pnl  -5.5120000000000005
# total pnl  -5.5120000000000005
# next trade hit
# SL HIT :  2024-12-05 09:31:00
# pnl  -5.975999999999999
# total pnl  -11.488
# next trade hit
# SL HIT :  2024-12-05 09:35:00
# pnl  -6.572000000000003
# total pnl  -18.060000000000002
# next trade hit
# SL HIT :  2024-12-05 09:38:00
# pnl  -7.156000000000006
# total pnl  -25.216000000000008
# next trade hit
# SL HIT :  2024-12-05 09:46:00
# pnl  -7.740000000000009
# total pnl  -32.95600000000002
# next trade hit
# SL HIT :  2024-12-05 09:48:00
# pnl  -8.640000000000015
# total pnl  -41.59600000000003
# next trade hit
# SL HIT :  2024-12-05 10:58:00
# pnl  -9.716000000000022
# total pnl  -51.312000000000054
# next trade hit
# INTRA SL HIT  20
# pnl  -27.819999999999993
# Processing file: C:\PICKLE\Nifty Future\2024-12-06_nifty_future.pkl
# sl price 61.56 ce pe price 57.0
# SL NOT HIT
# total pnl  35.6
# Processing file: C:\PICKLE\Nifty Future\2024-12-09_nifty_future.pkl
# sl price 58.75200000000001 ce pe price 54.400000000000006
# SL NOT HIT
# total pnl  17.35000000000001
# Processing file: C:\PICKLE\Nifty Future\2024-12-10_nifty_future.pkl
# sl price 75.33 ce pe price 69.75
# SL NOT HIT
# total pnl  22.25
# Processing file: C:\PICKLE\Nifty Future\2024-12-11_nifty_future.pkl
# sl price 61.344 ce pe price 56.8
# SL NOT HIT
# total pnl  26.199999999999996
# Processing file: C:\PICKLE\Nifty Future\2024-12-12_nifty_future.pkl
# sl price 61.12800000000001 ce pe price 56.6
# INTRA SL HIT  20
# pnl  -11.32
# Processing file: C:\PICKLE\Nifty Future\2024-12-13_nifty_future.pkl
# sl price 66.744 ce pe price 61.8
# SL HIT :  2024-12-13 10:20:00
# pnl  -4.944000000000003
# total pnl  -4.944000000000003
# next trade hit
# SL HIT :  2024-12-13 10:21:00
# pnl  -5.560000000000002
# total pnl  -10.504000000000005
# next trade hit
# SL HIT :  2024-12-13 10:30:00
# pnl  -6.204000000000008
# total pnl  -16.708000000000013
# next trade hit
# SL HIT :  2024-12-13 10:32:00
# pnl  -6.712000000000003
# total pnl  -23.420000000000016
# next trade hit
# SL NOT HIT
# total pnl  -8.070000000000022
# Processing file: C:\PICKLE\Nifty Future\2024-12-16_nifty_future.pkl
# sl price 54.486000000000004 ce pe price 50.45
# SL HIT :  2024-12-16 09:29:00
# pnl  -4.036000000000001
# total pnl  -4.036000000000001
# next trade hit
# SL HIT :  2024-12-16 09:33:00
# pnl  -4.436000000000007
# total pnl  -8.472000000000008
# next trade hit
# SL HIT :  2024-12-16 10:30:00
# pnl  -4.792000000000002
# total pnl  -13.26400000000001
# next trade hit
# INTRA SL HIT  20
# pnl  -13.009999999999991
# Processing file: C:\PICKLE\Nifty Future\2024-12-17_nifty_future.pkl
# sl price 76.356 ce pe price 70.69999999999999
# SL HIT :  2024-12-17 10:20:00
# pnl  -5.656000000000006
# total pnl  -5.656000000000006
# next trade hit
# SL HIT :  2024-12-17 10:21:00
# pnl  -6.400000000000006
# total pnl  -12.056000000000012
# next trade hit
# SL HIT :  2024-12-17 10:40:00
# pnl  -7.156000000000006
# total pnl  -19.212000000000018
# next trade hit
# SL NOT HIT
# total pnl  19.13799999999999
# Processing file: C:\PICKLE\Nifty Future\2024-12-18_nifty_future.pkl
# sl price 61.938 ce pe price 57.35
# SL NOT HIT
# total pnl  16.500000000000007
# Processing file: C:\PICKLE\Nifty Future\2024-12-19_nifty_future.pkl
# sl price 68.58 ce pe price 63.5
# SL HIT :  2024-12-19 09:21:00
# pnl  -5.079999999999998
# total pnl  -5.079999999999998
# next trade hit
# SL NOT HIT
# total pnl  64.47
# Processing file: C:\PICKLE\Nifty Future\2024-12-20_nifty_future.pkl
# sl price 60.96600000000001 ce pe price 56.45
# SL HIT :  2024-12-20 09:39:00
# pnl  -4.516000000000005
# total pnl  -4.516000000000005
# next trade hit
# SL HIT :  2024-12-20 09:51:00
# pnl  -5.040000000000006
# total pnl  -9.556000000000012
# next trade hit
# SL HIT :  2024-12-20 15:14:00
# pnl  -5.50800000000001
# total pnl  -15.064000000000021
# next trade hit
# SL NOT HIT
# total pnl  -4.564000000000021
# Processing file: C:\PICKLE\Nifty Future\2024-12-23_nifty_future.pkl
# sl price 65.88000000000001 ce pe price 61.0
# SL NOT HIT
# total pnl  35.8
# Processing file: C:\PICKLE\Nifty Future\2024-12-24_nifty_future.pkl
# sl price 57.78 ce pe price 53.5
# INTRA SL HIT  20
# pnl  -10.700000000000003
# Processing file: C:\PICKLE\Nifty Future\2024-12-26_nifty_future.pkl
# sl price 66.04200000000002 ce pe price 61.150000000000006
# INTRA SL HIT  20
# pnl  -12.230000000000004
# Processing file: C:\PICKLE\Nifty Future\2024-12-27_nifty_future.pkl
# sl price 66.15 ce pe price 61.25
# SL NOT HIT
# total pnl  31.6
# Processing file: C:\PICKLE\Nifty Future\2024-12-30_nifty_future.pkl
# sl price 59.508 ce pe price 55.1
# SL HIT :  2024-12-30 11:32:00
# pnl  -4.408000000000001
# total pnl  -4.408000000000001
# next trade hit
# SL HIT :  2024-12-30 11:47:00
# pnl  -4.95600000000001
# total pnl  -9.364000000000011
# next trade hit
# INTRA SL HIT  20
# pnl  -13.61
# Processing file: C:\PICKLE\Nifty Future\2024-12-31_nifty_future.pkl
# sl price 60.42600000000001 ce pe price 55.95
# SL HIT :  2024-12-31 09:39:00
# pnl  -4.476000000000006
# total pnl  -4.476000000000006
# next trade hit
# SL HIT :  2024-12-31 10:09:00
# pnl  -4.852000000000004
# total pnl  -9.32800000000001
# next trade hit
# SL HIT :  2024-12-31 10:52:00
# pnl  -5.372
# total pnl  -14.70000000000001
# next trade hit
# SL HIT :  2024-12-31 14:02:00
# pnl  -5.9280000000000115
# total pnl  -20.62800000000002
# next trade hit
# SL NOT HIT
# total pnl  -8.778000000000013
# All backtest results saved to all_backtest_trades.csv
